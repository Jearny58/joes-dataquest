# %% [markdown]
# ## Reading CSV Files with Encodings

# %%
# import pandas
import pandas as pd

# load data
laptops = pd.read_csv('data/laptops.csv', encoding='Latin-1')

laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
# Manufacturer                1303 non-null object
# Model Name                  1303 non-null object
# Category                    1303 non-null object
# Screen Size                 1303 non-null object
# Screen                      1303 non-null object
# CPU                         1303 non-null object
# RAM                         1303 non-null object
#  Storage                    1303 non-null object
# GPU                         1303 non-null object
# Operating System            1303 non-null object
# Operating System Version    1133 non-null object
# Weight                      1303 non-null object
# Price (Euros)               1303 non-null object
# dtypes: object(13)
# memory usage: 132.4+ KB

# %% [markdown]
# ## Cleaning Column Names

# %%
# define a function that accepts a string argument
def string_clean(string):
    string = string.strip()
    string = string.replace('Operating System', 'os')
    string = string.replace(" ", "_")
    string = string.replace('(','')
    string = string.replace(')','')
    string = string.lower()
    return string

# %%
laptops.columns = [string_clean(c) for c in laptops.columns]
laptops.columns
# Out:
# Index(['manufacturer', 'model_name', 'category', 'screen_size', 'screen',
#        'cpu', 'ram', 'storage', 'gpu', 'os', 'os_version', 'weight',
#        'price_euros'],
#       dtype='object')

# %% [markdown]
# ## Converting String Columns to Numeric

# %%
laptops['screen_size'] = (laptops['screen_size']
                          .str.replace('"','').astype(float)
                         )

laptops.rename({'screen_size':'screen_size_inches'}, axis=1, inplace=True)

# %%
# remove substring GB from the ram column
laptops['ram'] = laptops['ram'].str.replace('GB', '').astype(int)

# rename ram column to ram_gb
laptops.rename({'ram':'ram_gb'}, axis=1, inplace=True)

# get a list of the column names and types
dtypes = laptops.dtypes
dtypes
# Out:
# manufacturer           object
# model_name             object
# category               object
# screen_size_inches    float64
# screen                 object
# cpu                    object
# ram_gb                  int64
# storage                object
# gpu                    object
# os                     object
# os_version             object
# weight                 object
# price_euros            object
# dtype: object

# %% [markdown]
# ## Practicing Converting String Columns to Numeric

# %%
# clean the weight column and convert to float type
laptops['weight'] = (laptops['weight']
                    .str.replace('kgs','')
                    .str.replace('kg','')
                    .astype(float)
                    )

# rename the weight column to weight_kg
laptops.rename({'weight':'weight_kg'}, axis=1, inplace=True)

# clean the price_euros column
laptops['price_euros'] = (laptops['price_euros']
                         .str.replace(',','.')
                         .astype(float)
                         )

# descriptive stats for weight_kg and price_euros columns
weight_describe = laptops['weight_kg'].describe()
price_describe = laptops['price_euros'].describe()
print(weight_describe, price_describe)
# Out:
# count    1303.000000
# mean        2.038734
# std         0.665475
# min         0.690000
# 25%         1.500000
# 50%         2.040000
# 75%         2.300000
# max         4.700000
# Name: weight_kg, dtype: float64 count    1303.000000
# mean     1123.686992
# std       699.009043
# min       174.000000
# 25%       599.000000
# 50%       977.000000
# 75%      1487.880000
# max      6099.000000
# Name: price_euros, dtype: float64

# %% [markdown]
# ## Extracting Values from the Start of Strings

# %%
# extract manufacturer name from the gpu column
laptops['gpu_manufacturer'] = (laptops['gpu']
                               .str.split(n=1, expand=True)
                               .iloc[:,0]
                              )

# extract manufacturer name from the cpu column
laptops['cpu_manufacturer'] = (laptops['cpu']
                               .str.split(n=1, expand=True)
                               .iloc[:,0]
                              )

laptops.head(5)
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
# 2           HP       250 G6   Notebook                15.6
# 3        Apple  MacBook Pro  Ultrabook                15.4
# 4        Apple  MacBook Pro  Ultrabook                13.3
#
#                                screen                         cpu  ram_gb  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz       8
# 1                            1440x900        Intel Core i5 1.8GHz       8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz       8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz      16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz       8
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
# 2            256GB SSD         Intel HD Graphics 620  No OS        NaN
# 3            512GB SSD            AMD Radeon Pro 455  macOS        NaN
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS        NaN
#
#    weight_kg  price_euros gpu_manufacturer cpu_manufacturer
# 0       1.37      1339.69            Intel            Intel
# 1       1.34       898.94            Intel            Intel
# 2       1.86       575.00            Intel            Intel
# 3       1.83      2537.45              AMD            Intel
# 4       1.37      1803.60            Intel            Intel

# %% [markdown]
# ## Extracting Values from the End of Strings

# %%
laptops['screen'].unique().shape
# Out:
# (40,)

# %%
laptops['screen'].unique()[:10]
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800'], dtype=object)

# %%
print(laptops.loc[:9, "screen"].str.split(expand=True))
# Out:
#           0      1          2        3          4
# 0       IPS  Panel     Retina  Display  2560x1600
# 1  1440x900   None       None     None       None
# 2      Full     HD  1920x1080     None       None
# 3       IPS  Panel     Retina  Display  2880x1800
# 4       IPS  Panel     Retina  Display  2560x1600
# 5  1366x768   None       None     None       None
# 6       IPS  Panel     Retina  Display  2880x1800
# 7  1440x900   None       None     None       None
# 8      Full     HD  1920x1080     None       None
# 9       IPS  Panel       Full       HD  1920x1080

# %%
print(laptops.loc[:9, 'screen'].str.rsplit(n=1,expand=True))
# Out:
#                           0          1
# 0  IPS Panel Retina Display  2560x1600
# 1                  1440x900       None
# 2                   Full HD  1920x1080
# 3  IPS Panel Retina Display  2880x1800
# 4  IPS Panel Retina Display  2560x1600
# 5                  1366x768       None
# 6  IPS Panel Retina Display  2880x1800
# 7                  1440x900       None
# 8                   Full HD  1920x1080
# 9         IPS Panel Full HD  1920x1080

# %%
screen_res = laptops['screen'].str.rsplit(n=1, expand=True)

#give the columns string labels make them easier to work with
screen_res.columns = ['A', 'B']

# for rows where the value of column 'B' is null, fill in the value found in column 'A' for that row
screen_res.loc[screen_res['B'].isnull(), 'B'] = screen_res['A']

screen_res.iloc[:10]
# Out:
#                           A          B
# 0  IPS Panel Retina Display  2560x1600
# 1                  1440x900   1440x900
# 2                   Full HD  1920x1080
# 3  IPS Panel Retina Display  2880x1800
# 4  IPS Panel Retina Display  2560x1600
# 5                  1366x768   1366x768
# 6  IPS Panel Retina Display  2880x1800
# 7                  1440x900   1440x900
# 8                   Full HD  1920x1080
# 9         IPS Panel Full HD  1920x1080

# %%
# have extracted the resolution data, can now assign to a new column
laptops['screen_resolution'] = screen_res['B']

print(laptops['screen_resolution'].unique().shape, laptops['screen_resolution'].unique())
# Out:
# (15,) ['2560x1600' '1440x900' '1920x1080' '2880x1800' '1366x768' '2304x1440'
#  '3200x1800' '1920x1200' '2256x1504' '3840x2160' '2160x1440' '2560x1440'
#  '1600x900' '2736x1824' '2400x1600']

# %%
# now we want to do the same thing but for the cpu column

# %%
laptops['cpu'].unique().shape
# Out:
# (118,)

# %%
laptops['cpu'].unique()[:10]
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz'],
#       dtype=object)

# %%
print(laptops.loc[:9, "cpu"].str.split(expand=True))
# Out:
#        0          1     2       3       4
# 0  Intel       Core    i5  2.3GHz    None
# 1  Intel       Core    i5  1.8GHz    None
# 2  Intel       Core    i5   7200U  2.5GHz
# 3  Intel       Core    i7  2.7GHz    None
# 4  Intel       Core    i5  3.1GHz    None
# 5    AMD  A9-Series  9420    3GHz    None
# 6  Intel       Core    i7  2.2GHz    None
# 7  Intel       Core    i5  1.8GHz    None
# 8  Intel       Core    i7   8550U  1.8GHz
# 9  Intel       Core    i5   8250U  1.6GHz

# %%
print(laptops.loc[:9, 'cpu'].str.rsplit(n=1,expand=True))
# Out:
#                      0       1
# 0        Intel Core i5  2.3GHz
# 1        Intel Core i5  1.8GHz
# 2  Intel Core i5 7200U  2.5GHz
# 3        Intel Core i7  2.7GHz
# 4        Intel Core i5  3.1GHz
# 5   AMD A9-Series 9420    3GHz
# 6        Intel Core i7  2.2GHz
# 7        Intel Core i5  1.8GHz
# 8  Intel Core i7 8550U  1.8GHz
# 9  Intel Core i5 8250U  1.6GHz

# %%
cpu_speed = laptops['cpu'].str.rsplit(n=1, expand=True)

#give the columns string labels make them easier to work with
cpu_speed.columns = ['A', 'B']

cpu_speed.head(10)
# Out:
#                      A       B
# 0        Intel Core i5  2.3GHz
# 1        Intel Core i5  1.8GHz
# 2  Intel Core i5 7200U  2.5GHz
# 3        Intel Core i7  2.7GHz
# 4        Intel Core i5  3.1GHz
# 5   AMD A9-Series 9420    3GHz
# 6        Intel Core i7  2.2GHz
# 7        Intel Core i5  1.8GHz
# 8  Intel Core i7 8550U  1.8GHz
# 9  Intel Core i5 8250U  1.6GHz

# %%
cpu_speed['B'] = cpu_speed['B'].str.replace('GHz', '').astype(float)
cpu_speed.head(5)
# Out:
#                      A    B
# 0        Intel Core i5  2.3
# 1        Intel Core i5  1.8
# 2  Intel Core i5 7200U  2.5
# 3        Intel Core i7  2.7
# 4        Intel Core i5  3.1

# %%
# assign new column of cpu speeds as new column, cpu_speed_ghz, to laptops
laptops['cpu_speed_ghz'] = cpu_speed['B']

laptops.head(5)
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
# 2           HP       250 G6   Notebook                15.6
# 3        Apple  MacBook Pro  Ultrabook                15.4
# 4        Apple  MacBook Pro  Ultrabook                13.3
#
#                                screen                         cpu  ram_gb  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz       8
# 1                            1440x900        Intel Core i5 1.8GHz       8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz       8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz      16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz       8
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
# 2            256GB SSD         Intel HD Graphics 620  No OS        NaN
# 3            512GB SSD            AMD Radeon Pro 455  macOS        NaN
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS        NaN
#
#    weight_kg  price_euros gpu_manufacturer cpu_manufacturer screen_resolution  \
# 0       1.37      1339.69            Intel            Intel         2560x1600
# 1       1.34       898.94            Intel            Intel          1440x900
# 2       1.86       575.00            Intel            Intel         1920x1080
# 3       1.83      2537.45              AMD            Intel         2880x1800
# 4       1.37      1803.60            Intel            Intel         2560x1600
#
#    cpu_speed_ghz
# 0            2.3
# 1            1.8
# 2            2.5
# 3            2.7
# 4            3.1

# %%
laptops['cpu_speed_ghz'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Correcting Bad Values

# %%
mapping_dict = {
    'Android': 'Android',
    'Chrome OS': 'Chrome OS',
    'Linux': 'Linux',
    'Mac OS': 'macOS',
    'No OS': 'No OS',
    'Windows': 'Windows',
    'macOS': 'macOS'
}

# use Series.map() method with mapping_dict dictionary to correct the values in the os column
laptops['os'] = laptops['os'].map(mapping_dict)

# %% [markdown]
# ## Dropping Missing Values

# %%
# remove any rows from the laptops df that have null values
laptops_no_null_rows = laptops.dropna()

# remove any columns from the laptops df that have null values
laptops_no_null_cols = laptops.dropna(axis=1)

# %%
laptops_no_null_rows
# Out:
#      manufacturer                                 model_name  \
# 5            Acer                                   Aspire 3
# 6           Apple                                MacBook Pro
# 8            Asus                            ZenBook UX430UN
# 9            Acer                                    Swift 3
# 13           Dell                              Inspiron 3567
# 16           Dell                              Inspiron 3567
# 19           Dell                                     XPS 13
# 20           Asus                            Vivobook E200HA
# 21         Lenovo                         Legion Y520-15IKBN
# 23           Dell                              Inspiron 5379
# 24             HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25           Dell                              Inspiron 3567
# 26          Apple                                MacBook Air
# 27           Dell                              Inspiron 5570
# 28           Dell                              Latitude 5590
# 29             HP                                ProBook 470
# 30          Chuwi                              LapBook 15.6"
# 31           Asus       E402WA-GA010T (E2-6110/2GB/32GB/W10)
# 32             HP       17-ak001nv (A6-9220/4GB/500GB/Radeon
# 33           Dell                                     XPS 13
# 34          Apple                                MacBook Air
# 35         Lenovo                         IdeaPad 120S-14IAP
# 37           Dell                              Inspiron 5770
# 38             HP                                     250 G6
# 39             HP                                ProBook 450
# 41           Dell                              Inspiron 7577
# 43           Acer                            Aspire A515-51G
# 44           Dell                              Inspiron 7773
# 47           Asus                                  Rog Strix
# 48           Dell                              Inspiron 3567
# ...           ...                                        ...
# 1269         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1270       Lenovo                             Yoga 500-14ISK
# 1271       Lenovo                             Yoga 900-13ISK
# 1272       Lenovo                         IdeaPad 100S-14IBR
# 1273           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1274         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1275         Asus                       ZenBook UX305CA-UBM1
# 1276         Dell                              Inspiron 3567
# 1278         Dell                              Inspiron 3552
# 1279       Lenovo                         IdeaPad Y700-15ISK
# 1280           HP                        Pavilion 15-AW003nv
# 1282           HP                           Stream 11-Y000na
# 1283         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1284       Lenovo                             Yoga 500-14ISK
# 1285       Lenovo                             Yoga 900-13ISK
# 1286       Lenovo                         IdeaPad 100S-14IBR
# 1287           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1288         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1289         Asus                       ZenBook UX305CA-UBM1
# 1290         Dell                              Inspiron 3567
# 1292         Dell                              Inspiron 3552
# 1293       Lenovo                         IdeaPad Y700-15ISK
# 1294           HP                        Pavilion 15-AW003nv
# 1296           HP                           Stream 11-Y000na
# 1297         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       Lenovo                             Yoga 500-14ISK
# 1299       Lenovo                             Yoga 900-13ISK
# 1300       Lenovo                         IdeaPad 100S-14IBR
# 1301           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 category  screen_size_inches  \
# 5               Notebook                15.6
# 6              Ultrabook                15.4
# 8              Ultrabook                14.0
# 9              Ultrabook                14.0
# 13              Notebook                15.6
# 16              Notebook                15.6
# 19             Ultrabook                13.3
# 20               Netbook                11.6
# 21                Gaming                15.6
# 23    2 in 1 Convertible                13.3
# 24             Ultrabook                15.6
# 25              Notebook                15.6
# 26             Ultrabook                13.3
# 27              Notebook                15.6
# 28             Ultrabook                15.6
# 29              Notebook                17.3
# 30              Notebook                15.6
# 31              Notebook                14.0
# 32              Notebook                17.3
# 33             Ultrabook                13.3
# 34             Ultrabook                13.3
# 35              Notebook                14.0
# 37              Notebook                17.3
# 38              Notebook                15.6
# 39              Notebook                15.6
# 41                Gaming                15.6
# 43              Notebook                15.6
# 44    2 in 1 Convertible                17.3
# 47                Gaming                17.3
# 48              Notebook                15.6
# ...                  ...                 ...
# 1269            Notebook                15.6
# 1270  2 in 1 Convertible                14.0
# 1271  2 in 1 Convertible                13.3
# 1272            Notebook                14.0
# 1273            Notebook                15.6
# 1274            Notebook                15.6
# 1275           Ultrabook                13.3
# 1276            Notebook                15.6
# 1278            Notebook                15.6
# 1279            Notebook                15.6
# 1280            Notebook                15.6
# 1282             Netbook                11.6
# 1283            Notebook                15.6
# 1284  2 in 1 Convertible                14.0
# 1285  2 in 1 Convertible                13.3
# 1286            Notebook                14.0
# 1287            Notebook                15.6
# 1288            Notebook                15.6
# 1289           Ultrabook                13.3
# 1290            Notebook                15.6
# 1292            Notebook                15.6
# 1293            Notebook                15.6
# 1294            Notebook                15.6
# 1296             Netbook                11.6
# 1297            Notebook                15.6
# 1298  2 in 1 Convertible                14.0
# 1299  2 in 1 Convertible                13.3
# 1300            Notebook                14.0
# 1301            Notebook                15.6
# 1302            Notebook                15.6
#
#                                           screen  \
# 5                                       1366x768
# 6             IPS Panel Retina Display 2880x1800
# 8                              Full HD 1920x1080
# 9                    IPS Panel Full HD 1920x1080
# 13                             Full HD 1920x1080
# 16                             Full HD 1920x1080
# 19     IPS Panel Full HD / Touchscreen 1920x1080
# 20                                      1366x768
# 21                   IPS Panel Full HD 1920x1080
# 23               Full HD / Touchscreen 1920x1080
# 24                             Full HD 1920x1080
# 25                                      1366x768
# 26                                      1440x900
# 27                             Full HD 1920x1080
# 28                             Full HD 1920x1080
# 29                             Full HD 1920x1080
# 30                             Full HD 1920x1080
# 31                                      1366x768
# 32                             Full HD 1920x1080
# 33              Touchscreen / Quad HD+ 3200x1800
# 34                                      1440x900
# 35                                      1366x768
# 37                   IPS Panel Full HD 1920x1080
# 38                                      1366x768
# 39                             Full HD 1920x1080
# 41                   IPS Panel Full HD 1920x1080
# 43                   IPS Panel Full HD 1920x1080
# 44               Full HD / Touchscreen 1920x1080
# 47                             Full HD 1920x1080
# 48                             Full HD 1920x1080
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
# 1274                                    1366x768
# 1275                 IPS Panel Full HD 1920x1080
# 1276                                    1366x768
# 1278                                    1366x768
# 1279                 IPS Panel Full HD 1920x1080
# 1280                           Full HD 1920x1080
# 1282                                    1366x768
# 1283                                    1366x768
# 1284   IPS Panel Full HD / Touchscreen 1920x1080
# 1285  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286                                    1366x768
# 1287                                    1366x768
# 1288                                    1366x768
# 1289                 IPS Panel Full HD 1920x1080
# 1290                                    1366x768
# 1292                                    1366x768
# 1293                 IPS Panel Full HD 1920x1080
# 1294                           Full HD 1920x1080
# 1296                                    1366x768
# 1297                                    1366x768
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        cpu  ram_gb                 storage  \
# 5                  AMD A9-Series 9420 3GHz       4               500GB HDD
# 6                     Intel Core i7 2.2GHz      16     256GB Flash Storage
# 8               Intel Core i7 8550U 1.8GHz      16               512GB SSD
# 9               Intel Core i5 8250U 1.6GHz       8               256GB SSD
# 13                Intel Core i3 6006U 2GHz       4               256GB SSD
# 16              Intel Core i7 7500U 2.7GHz       8               256GB SSD
# 19              Intel Core i5 8250U 1.6GHz       8               128GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz       2      32GB Flash Storage
# 21             Intel Core i5 7300HQ 2.5GHz       8    128GB SSD +  1TB HDD
# 23              Intel Core i5 8250U 1.6GHz       8               256GB SSD
# 24              Intel Core i7 8550U 1.8GHz       8               256GB SSD
# 25                Intel Core i3 6006U 2GHz       4                 1TB HDD
# 26                    Intel Core i5 1.6GHz       8     128GB Flash Storage
# 27              Intel Core i5 8250U 1.6GHz       8               256GB SSD
# 28              Intel Core i7 8650U 1.9GHz       8  256GB SSD +  256GB SSD
# 29              Intel Core i5 8250U 1.6GHz       8                 1TB HDD
# 30             Intel Atom x5-Z8300 1.44GHz       4      64GB Flash Storage
# 31             AMD E-Series E2-6110 1.5GHz       2      32GB Flash Storage
# 32               AMD A6-Series 9220 2.5GHz       4               500GB HDD
# 33              Intel Core i7 8550U 1.8GHz      16               512GB SSD
# 34                    Intel Core i5 1.6GHz       8     256GB Flash Storage
# 35    Intel Celeron Dual Core N3350 1.1GHz       4      64GB Flash Storage
# 37              Intel Core i5 8250U 1.6GHz       8    128GB SSD +  1TB HDD
# 38              Intel Core i5 7200U 2.5GHz       4                 1TB HDD
# 39              Intel Core i5 8250U 1.6GHz       8               256GB SSD
# 41             Intel Core i7 7700HQ 2.8GHz      16    256GB SSD +  1TB HDD
# 43              Intel Core i5 8250U 1.6GHz       4               256GB SSD
# 44              Intel Core i5 8250U 1.6GHz      12                 1TB HDD
# 47                     AMD Ryzen 1700 3GHz       8    256GB SSD +  1TB HDD
# 48              Intel Core i5 7200U 2.5GHz       4               256GB SSD
# ...                                    ...     ...                     ...
# 1269            Intel Core i7 6500U 2.5GHz       4               500GB HDD
# 1270            Intel Core i7 6500U 2.5GHz       4               128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz      16               512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz       2      64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz       6                 1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz       4               500GB HDD
# 1275              Intel Core M 6Y30 0.9GHz       8               512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz       6                 1TB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz       2               500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz       8                 1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz       6              1TB Hybrid
# 1282  Intel Celeron Dual Core N3060 1.6GHz       2      32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz       4               500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz       4               128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz      16               512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz       2      64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz       6                 1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz       4               500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz       8               512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz       6                 1TB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz       2               500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz       8                 1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz       6              1TB Hybrid
# 1296  Intel Celeron Dual Core N3060 1.6GHz       2      32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz       4               500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz       4               128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz      16               512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz       2      64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz       6                 1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz       4               500GB HDD
#
#                           gpu       os os_version  weight_kg  price_euros  \
# 5               AMD Radeon R5  Windows         10       2.10       400.00
# 6     Intel Iris Pro Graphics    macOS          X       2.04      2139.97
# 8        Nvidia GeForce MX150  Windows         10       1.30      1495.00
# 9      Intel UHD Graphics 620  Windows         10       1.60       770.00
# 13         AMD Radeon R5 M430  Windows         10       2.20       498.90
# 16         AMD Radeon R5 M430  Windows         10       2.20       745.00
# 19     Intel UHD Graphics 620  Windows         10       1.22       979.00
# 20      Intel HD Graphics 400  Windows         10       0.98       191.90
# 21    Nvidia GeForce GTX 1050  Windows         10       2.50       999.00
# 23     Intel UHD Graphics 620  Windows         10       1.62       819.00
# 24      Intel HD Graphics 620  Windows         10       1.91       659.00
# 25      Intel HD Graphics 520  Windows         10       2.30       418.64
# 26     Intel HD Graphics 6000    macOS          X       1.35      1099.00
# 27             AMD Radeon 530  Windows         10       2.20       800.00
# 28     Intel UHD Graphics 620  Windows         10       1.88      1298.00
# 29       Nvidia GeForce 930MX  Windows         10       2.50       896.00
# 30          Intel HD Graphics  Windows         10       1.89       244.99
# 31              AMD Radeon R2  Windows         10       1.65       199.00
# 32             AMD Radeon 530  Windows         10       2.71       439.00
# 33     Intel UHD Graphics 620  Windows         10       1.20      1869.00
# 34     Intel HD Graphics 6000    macOS          X       1.35       998.00
# 35      Intel HD Graphics 500  Windows         10       1.44       249.00
# 37             AMD Radeon 530  Windows         10       2.80       979.00
# 38      Intel HD Graphics 620  Windows         10       1.86       488.69
# 39      Nvidia GeForce 930MX   Windows         10       2.10       879.00
# 41    Nvidia GeForce GTX 1060  Windows         10       2.65      1499.00
# 43     Intel UHD Graphics 620  Windows         10       2.20       682.00
# 44       Nvidia GeForce 150MX  Windows         10       2.77       999.00
# 47          AMD Radeon RX 580  Windows         10       3.20      1299.00
# 48         AMD Radeon R5 M430  Windows         10       2.30       639.00
# ...                       ...      ...        ...        ...          ...
# 1269      Nvidia GeForce 920M  Windows         10       2.20       720.32
# 1270    Intel HD Graphics 520  Windows         10       1.80       638.00
# 1271    Intel HD Graphics 520  Windows         10       1.30      1499.00
# 1272        Intel HD Graphics  Windows         10       1.50       229.00
# 1273       AMD Radeon R5 M330  Windows         10       2.19       764.00
# 1274        Intel HD Graphics  Windows         10       2.20       369.00
# 1275    Intel HD Graphics 515  Windows         10       1.20       729.00
# 1276    Intel HD Graphics 620  Windows         10       2.30       459.00
# 1278        Intel HD Graphics  Windows         10       2.20       379.00
# 1279  Nvidia GeForce GTX 960M  Windows         10       2.60       899.00
# 1280       AMD Radeon R7 M440  Windows         10       2.04       549.99
# 1282    Intel HD Graphics 400  Windows         10       1.17       209.00
# 1283      Nvidia GeForce 920M  Windows         10       2.20       720.32
# 1284    Intel HD Graphics 520  Windows         10       1.80       638.00
# 1285    Intel HD Graphics 520  Windows         10       1.30      1499.00
# 1286        Intel HD Graphics  Windows         10       1.50       229.00
# 1287       AMD Radeon R5 M330  Windows         10       2.19       764.00
# 1288        Intel HD Graphics  Windows         10       2.20       369.00
# 1289    Intel HD Graphics 515  Windows         10       1.20       729.00
# 1290    Intel HD Graphics 620  Windows         10       2.30       459.00
# 1292        Intel HD Graphics  Windows         10       2.20       379.00
# 1293  Nvidia GeForce GTX 960M  Windows         10       2.60       899.00
# 1294       AMD Radeon R7 M440  Windows         10       2.04       549.99
# 1296    Intel HD Graphics 400  Windows         10       1.17       209.00
# 1297      Nvidia GeForce 920M  Windows         10       2.20       720.32
# 1298    Intel HD Graphics 520  Windows         10       1.80       638.00
# 1299    Intel HD Graphics 520  Windows         10       1.30      1499.00
# 1300        Intel HD Graphics  Windows         10       1.50       229.00
# 1301       AMD Radeon R5 M330  Windows         10       2.19       764.00
# 1302        Intel HD Graphics  Windows         10       2.20       369.00
#
#      gpu_manufacturer cpu_manufacturer screen_resolution  cpu_speed_ghz
# 5                 AMD              AMD          1366x768           3.00
# 6               Intel            Intel         2880x1800           2.20
# 8              Nvidia            Intel         1920x1080           1.80
# 9               Intel            Intel         1920x1080           1.60
# 13                AMD            Intel         1920x1080           2.00
# 16                AMD            Intel         1920x1080           2.70
# 19              Intel            Intel         1920x1080           1.60
# 20              Intel            Intel          1366x768           1.44
# 21             Nvidia            Intel         1920x1080           2.50
# 23              Intel            Intel         1920x1080           1.60
# 24              Intel            Intel         1920x1080           1.80
# 25              Intel            Intel          1366x768           2.00
# 26              Intel            Intel          1440x900           1.60
# 27                AMD            Intel         1920x1080           1.60
# 28              Intel            Intel         1920x1080           1.90
# 29             Nvidia            Intel         1920x1080           1.60
# 30              Intel            Intel         1920x1080           1.44
# 31                AMD              AMD          1366x768           1.50
# 32                AMD              AMD         1920x1080           2.50
# 33              Intel            Intel         3200x1800           1.80
# 34              Intel            Intel          1440x900           1.60
# 35              Intel            Intel          1366x768           1.10
# 37                AMD            Intel         1920x1080           1.60
# 38              Intel            Intel          1366x768           2.50
# 39             Nvidia            Intel         1920x1080           1.60
# 41             Nvidia            Intel         1920x1080           2.80
# 43              Intel            Intel         1920x1080           1.60
# 44             Nvidia            Intel         1920x1080           1.60
# 47                AMD              AMD         1920x1080           3.00
# 48                AMD            Intel         1920x1080           2.50
# ...               ...              ...               ...            ...
# 1269           Nvidia            Intel          1366x768           2.50
# 1270            Intel            Intel         1920x1080           2.50
# 1271            Intel            Intel         3200x1800           2.50
# 1272            Intel            Intel          1366x768           1.60
# 1273              AMD            Intel          1366x768           2.50
# 1274            Intel            Intel          1366x768           1.60
# 1275            Intel            Intel         1920x1080           0.90
# 1276            Intel            Intel          1366x768           2.40
# 1278            Intel            Intel          1366x768           1.60
# 1279           Nvidia            Intel         1920x1080           2.60
# 1280              AMD              AMD         1920x1080           2.90
# 1282            Intel            Intel          1366x768           1.60
# 1283           Nvidia            Intel          1366x768           2.50
# 1284            Intel            Intel         1920x1080           2.50
# 1285            Intel            Intel         3200x1800           2.50
# 1286            Intel            Intel          1366x768           1.60
# 1287              AMD            Intel          1366x768           2.50
# 1288            Intel            Intel          1366x768           1.60
# 1289            Intel            Intel         1920x1080           0.90
# 1290            Intel            Intel          1366x768           2.40
# 1292            Intel            Intel          1366x768           1.60
# 1293           Nvidia            Intel         1920x1080           2.60
# 1294              AMD              AMD         1920x1080           2.90
# 1296            Intel            Intel          1366x768           1.60
# 1297           Nvidia            Intel          1366x768           2.50
# 1298            Intel            Intel         1920x1080           2.50
# 1299            Intel            Intel         3200x1800           2.50
# 1300            Intel            Intel          1366x768           1.60
# 1301              AMD            Intel          1366x768           2.50
# 1302            Intel            Intel          1366x768           1.60
#
# [1133 rows x 17 columns]

# %%
laptops_no_null_cols
# Out:
#      manufacturer                                 model_name  \
# 0           Apple                                MacBook Pro
# 1           Apple                                Macbook Air
# 2              HP                                     250 G6
# 3           Apple                                MacBook Pro
# 4           Apple                                MacBook Pro
# 5            Acer                                   Aspire 3
# 6           Apple                                MacBook Pro
# 7           Apple                                Macbook Air
# 8            Asus                            ZenBook UX430UN
# 9            Acer                                    Swift 3
# 10             HP                                     250 G6
# 11             HP                                     250 G6
# 12          Apple                                MacBook Pro
# 13           Dell                              Inspiron 3567
# 14          Apple                                MacBook 12"
# 15          Apple                                MacBook Pro
# 16           Dell                              Inspiron 3567
# 17          Apple                                MacBook Pro
# 18         Lenovo                          IdeaPad 320-15IKB
# 19           Dell                                     XPS 13
# 20           Asus                            Vivobook E200HA
# 21         Lenovo                         Legion Y520-15IKBN
# 22             HP                                     255 G6
# 23           Dell                              Inspiron 5379
# 24             HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25           Dell                              Inspiron 3567
# 26          Apple                                MacBook Air
# 27           Dell                              Inspiron 5570
# 28           Dell                              Latitude 5590
# 29             HP                                ProBook 470
# ...           ...                                        ...
# 1273           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1274         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1275         Asus                       ZenBook UX305CA-UBM1
# 1276         Dell                              Inspiron 3567
# 1277         Acer                             Aspire ES1-531
# 1278         Dell                              Inspiron 3552
# 1279       Lenovo                         IdeaPad Y700-15ISK
# 1280           HP                        Pavilion 15-AW003nv
# 1281         Dell                              Inspiron 3567
# 1282           HP                           Stream 11-Y000na
# 1283         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1284       Lenovo                             Yoga 500-14ISK
# 1285       Lenovo                             Yoga 900-13ISK
# 1286       Lenovo                         IdeaPad 100S-14IBR
# 1287           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1288         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1289         Asus                       ZenBook UX305CA-UBM1
# 1290         Dell                              Inspiron 3567
# 1291         Acer                             Aspire ES1-531
# 1292         Dell                              Inspiron 3552
# 1293       Lenovo                         IdeaPad Y700-15ISK
# 1294           HP                        Pavilion 15-AW003nv
# 1295         Dell                              Inspiron 3567
# 1296           HP                           Stream 11-Y000na
# 1297         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       Lenovo                             Yoga 500-14ISK
# 1299       Lenovo                             Yoga 900-13ISK
# 1300       Lenovo                         IdeaPad 100S-14IBR
# 1301           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 category  screen_size_inches  \
# 0              Ultrabook                13.3
# 1              Ultrabook                13.3
# 2               Notebook                15.6
# 3              Ultrabook                15.4
# 4              Ultrabook                13.3
# 5               Notebook                15.6
# 6              Ultrabook                15.4
# 7              Ultrabook                13.3
# 8              Ultrabook                14.0
# 9              Ultrabook                14.0
# 10              Notebook                15.6
# 11              Notebook                15.6
# 12             Ultrabook                15.4
# 13              Notebook                15.6
# 14             Ultrabook                12.0
# 15             Ultrabook                13.3
# 16              Notebook                15.6
# 17             Ultrabook                15.4
# 18              Notebook                15.6
# 19             Ultrabook                13.3
# 20               Netbook                11.6
# 21                Gaming                15.6
# 22              Notebook                15.6
# 23    2 in 1 Convertible                13.3
# 24             Ultrabook                15.6
# 25              Notebook                15.6
# 26             Ultrabook                13.3
# 27              Notebook                15.6
# 28             Ultrabook                15.6
# 29              Notebook                17.3
# ...                  ...                 ...
# 1273            Notebook                15.6
# 1274            Notebook                15.6
# 1275           Ultrabook                13.3
# 1276            Notebook                15.6
# 1277            Notebook                15.6
# 1278            Notebook                15.6
# 1279            Notebook                15.6
# 1280            Notebook                15.6
# 1281            Notebook                15.6
# 1282             Netbook                11.6
# 1283            Notebook                15.6
# 1284  2 in 1 Convertible                14.0
# 1285  2 in 1 Convertible                13.3
# 1286            Notebook                14.0
# 1287            Notebook                15.6
# 1288            Notebook                15.6
# 1289           Ultrabook                13.3
# 1290            Notebook                15.6
# 1291            Notebook                15.6
# 1292            Notebook                15.6
# 1293            Notebook                15.6
# 1294            Notebook                15.6
# 1295            Notebook                15.6
# 1296             Netbook                11.6
# 1297            Notebook                15.6
# 1298  2 in 1 Convertible                14.0
# 1299  2 in 1 Convertible                13.3
# 1300            Notebook                14.0
# 1301            Notebook                15.6
# 1302            Notebook                15.6
#
#                                           screen  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# 5                                       1366x768
# 6             IPS Panel Retina Display 2880x1800
# 7                                       1440x900
# 8                              Full HD 1920x1080
# 9                    IPS Panel Full HD 1920x1080
# 10                                      1366x768
# 11                             Full HD 1920x1080
# 12            IPS Panel Retina Display 2880x1800
# 13                             Full HD 1920x1080
# 14            IPS Panel Retina Display 2304x1440
# 15            IPS Panel Retina Display 2560x1600
# 16                             Full HD 1920x1080
# 17            IPS Panel Retina Display 2880x1800
# 18                             Full HD 1920x1080
# 19     IPS Panel Full HD / Touchscreen 1920x1080
# 20                                      1366x768
# 21                   IPS Panel Full HD 1920x1080
# 22                                      1366x768
# 23               Full HD / Touchscreen 1920x1080
# 24                             Full HD 1920x1080
# 25                                      1366x768
# 26                                      1440x900
# 27                             Full HD 1920x1080
# 28                             Full HD 1920x1080
# 29                             Full HD 1920x1080
# ...                                          ...
# 1273                                    1366x768
# 1274                                    1366x768
# 1275                 IPS Panel Full HD 1920x1080
# 1276                                    1366x768
# 1277                                    1366x768
# 1278                                    1366x768
# 1279                 IPS Panel Full HD 1920x1080
# 1280                           Full HD 1920x1080
# 1281                                    1366x768
# 1282                                    1366x768
# 1283                                    1366x768
# 1284   IPS Panel Full HD / Touchscreen 1920x1080
# 1285  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286                                    1366x768
# 1287                                    1366x768
# 1288                                    1366x768
# 1289                 IPS Panel Full HD 1920x1080
# 1290                                    1366x768
# 1291                                    1366x768
# 1292                                    1366x768
# 1293                 IPS Panel Full HD 1920x1080
# 1294                           Full HD 1920x1080
# 1295                                    1366x768
# 1296                                    1366x768
# 1297                                    1366x768
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        cpu  ram_gb                 storage  \
# 0                     Intel Core i5 2.3GHz       8               128GB SSD
# 1                     Intel Core i5 1.8GHz       8     128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz       8               256GB SSD
# 3                     Intel Core i7 2.7GHz      16               512GB SSD
# 4                     Intel Core i5 3.1GHz       8               256GB SSD
# 5                  AMD A9-Series 9420 3GHz       4               500GB HDD
# 6                     Intel Core i7 2.2GHz      16     256GB Flash Storage
# 7                     Intel Core i5 1.8GHz       8     256GB Flash Storage
# 8               Intel Core i7 8550U 1.8GHz      16               512GB SSD
# 9               Intel Core i5 8250U 1.6GHz       8               256GB SSD
# 10              Intel Core i5 7200U 2.5GHz       4               500GB HDD
# 11                Intel Core i3 6006U 2GHz       4               500GB HDD
# 12                    Intel Core i7 2.8GHz      16               256GB SSD
# 13                Intel Core i3 6006U 2GHz       4               256GB SSD
# 14                  Intel Core M m3 1.2GHz       8               256GB SSD
# 15                    Intel Core i5 2.3GHz       8               256GB SSD
# 16              Intel Core i7 7500U 2.7GHz       8               256GB SSD
# 17                    Intel Core i7 2.9GHz      16               512GB SSD
# 18              Intel Core i3 7100U 2.4GHz       8                 1TB HDD
# 19              Intel Core i5 8250U 1.6GHz       8               128GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz       2      32GB Flash Storage
# 21             Intel Core i5 7300HQ 2.5GHz       8    128GB SSD +  1TB HDD
# 22            AMD E-Series E2-9000e 1.5GHz       4               500GB HDD
# 23              Intel Core i5 8250U 1.6GHz       8               256GB SSD
# 24              Intel Core i7 8550U 1.8GHz       8               256GB SSD
# 25                Intel Core i3 6006U 2GHz       4                 1TB HDD
# 26                    Intel Core i5 1.6GHz       8     128GB Flash Storage
# 27              Intel Core i5 8250U 1.6GHz       8               256GB SSD
# 28              Intel Core i7 8650U 1.9GHz       8  256GB SSD +  256GB SSD
# 29              Intel Core i5 8250U 1.6GHz       8                 1TB HDD
# ...                                    ...     ...                     ...
# 1273            Intel Core i7 6500U 2.5GHz       6                 1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz       4               500GB HDD
# 1275              Intel Core M 6Y30 0.9GHz       8               512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz       6                 1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz       4               500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz       2               500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz       8                 1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz       6              1TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz       8                 1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz       2      32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz       4               500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz       4               128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz      16               512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz       2      64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz       6                 1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz       4               500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz       8               512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz       6                 1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz       4               500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz       2               500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz       8                 1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz       6              1TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz       8                 1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz       2      32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz       4               500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz       4               128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz      16               512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz       2      64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz       6                 1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz       4               500GB HDD
#
#                                gpu       os  weight_kg  price_euros  \
# 0     Intel Iris Plus Graphics 640    macOS       1.37      1339.69
# 1           Intel HD Graphics 6000    macOS       1.34       898.94
# 2            Intel HD Graphics 620    No OS       1.86       575.00
# 3               AMD Radeon Pro 455    macOS       1.83      2537.45
# 4     Intel Iris Plus Graphics 650    macOS       1.37      1803.60
# 5                    AMD Radeon R5  Windows       2.10       400.00
# 6          Intel Iris Pro Graphics    macOS       2.04      2139.97
# 7           Intel HD Graphics 6000    macOS       1.34      1158.70
# 8             Nvidia GeForce MX150  Windows       1.30      1495.00
# 9           Intel UHD Graphics 620  Windows       1.60       770.00
# 10           Intel HD Graphics 620    No OS       1.86       393.90
# 11           Intel HD Graphics 520    No OS       1.86       344.99
# 12              AMD Radeon Pro 555    macOS       1.83      2439.97
# 13              AMD Radeon R5 M430  Windows       2.20       498.90
# 14           Intel HD Graphics 615    macOS       0.92      1262.40
# 15    Intel Iris Plus Graphics 640    macOS       1.37      1518.55
# 16              AMD Radeon R5 M430  Windows       2.20       745.00
# 17              AMD Radeon Pro 560    macOS       1.83      2858.00
# 18            Nvidia GeForce 940MX    No OS       2.20       499.00
# 19          Intel UHD Graphics 620  Windows       1.22       979.00
# 20           Intel HD Graphics 400  Windows       0.98       191.90
# 21         Nvidia GeForce GTX 1050  Windows       2.50       999.00
# 22                   AMD Radeon R2    No OS       1.86       258.00
# 23          Intel UHD Graphics 620  Windows       1.62       819.00
# 24           Intel HD Graphics 620  Windows       1.91       659.00
# 25           Intel HD Graphics 520  Windows       2.30       418.64
# 26          Intel HD Graphics 6000    macOS       1.35      1099.00
# 27                  AMD Radeon 530  Windows       2.20       800.00
# 28          Intel UHD Graphics 620  Windows       1.88      1298.00
# 29            Nvidia GeForce 930MX  Windows       2.50       896.00
# ...                            ...      ...        ...          ...
# 1273            AMD Radeon R5 M330  Windows       2.19       764.00
# 1274             Intel HD Graphics  Windows       2.20       369.00
# 1275         Intel HD Graphics 515  Windows       1.20       729.00
# 1276         Intel HD Graphics 620  Windows       2.30       459.00
# 1277         Intel HD Graphics 400    Linux       2.40       289.00
# 1278             Intel HD Graphics  Windows       2.20       379.00
# 1279       Nvidia GeForce GTX 960M  Windows       2.60       899.00
# 1280            AMD Radeon R7 M440  Windows       2.04       549.99
# 1281            AMD Radeon R5 M430    Linux       2.30       805.99
# 1282         Intel HD Graphics 400  Windows       1.17       209.00
# 1283           Nvidia GeForce 920M  Windows       2.20       720.32
# 1284         Intel HD Graphics 520  Windows       1.80       638.00
# 1285         Intel HD Graphics 520  Windows       1.30      1499.00
# 1286             Intel HD Graphics  Windows       1.50       229.00
# 1287            AMD Radeon R5 M330  Windows       2.19       764.00
# 1288             Intel HD Graphics  Windows       2.20       369.00
# 1289         Intel HD Graphics 515  Windows       1.20       729.00
# 1290         Intel HD Graphics 620  Windows       2.30       459.00
# 1291         Intel HD Graphics 400    Linux       2.40       289.00
# 1292             Intel HD Graphics  Windows       2.20       379.00
# 1293       Nvidia GeForce GTX 960M  Windows       2.60       899.00
# 1294            AMD Radeon R7 M440  Windows       2.04       549.99
# 1295            AMD Radeon R5 M430    Linux       2.30       805.99
# 1296         Intel HD Graphics 400  Windows       1.17       209.00
# 1297           Nvidia GeForce 920M  Windows       2.20       720.32
# 1298         Intel HD Graphics 520  Windows       1.80       638.00
# 1299         Intel HD Graphics 520  Windows       1.30      1499.00
# 1300             Intel HD Graphics  Windows       1.50       229.00
# 1301            AMD Radeon R5 M330  Windows       2.19       764.00
# 1302             Intel HD Graphics  Windows       2.20       369.00
#
#      gpu_manufacturer cpu_manufacturer screen_resolution  cpu_speed_ghz
# 0               Intel            Intel         2560x1600           2.30
# 1               Intel            Intel          1440x900           1.80
# 2               Intel            Intel         1920x1080           2.50
# 3                 AMD            Intel         2880x1800           2.70
# 4               Intel            Intel         2560x1600           3.10
# 5                 AMD              AMD          1366x768           3.00
# 6               Intel            Intel         2880x1800           2.20
# 7               Intel            Intel          1440x900           1.80
# 8              Nvidia            Intel         1920x1080           1.80
# 9               Intel            Intel         1920x1080           1.60
# 10              Intel            Intel          1366x768           2.50
# 11              Intel            Intel         1920x1080           2.00
# 12                AMD            Intel         2880x1800           2.80
# 13                AMD            Intel         1920x1080           2.00
# 14              Intel            Intel         2304x1440           1.20
# 15              Intel            Intel         2560x1600           2.30
# 16                AMD            Intel         1920x1080           2.70
# 17                AMD            Intel         2880x1800           2.90
# 18             Nvidia            Intel         1920x1080           2.40
# 19              Intel            Intel         1920x1080           1.60
# 20              Intel            Intel          1366x768           1.44
# 21             Nvidia            Intel         1920x1080           2.50
# 22                AMD              AMD          1366x768           1.50
# 23              Intel            Intel         1920x1080           1.60
# 24              Intel            Intel         1920x1080           1.80
# 25              Intel            Intel          1366x768           2.00
# 26              Intel            Intel          1440x900           1.60
# 27                AMD            Intel         1920x1080           1.60
# 28              Intel            Intel         1920x1080           1.90
# 29             Nvidia            Intel         1920x1080           1.60
# ...               ...              ...               ...            ...
# 1273              AMD            Intel          1366x768           2.50
# 1274            Intel            Intel          1366x768           1.60
# 1275            Intel            Intel         1920x1080           0.90
# 1276            Intel            Intel          1366x768           2.40
# 1277            Intel            Intel          1366x768           1.60
# 1278            Intel            Intel          1366x768           1.60
# 1279           Nvidia            Intel         1920x1080           2.60
# 1280              AMD              AMD         1920x1080           2.90
# 1281              AMD            Intel          1366x768           2.70
# 1282            Intel            Intel          1366x768           1.60
# 1283           Nvidia            Intel          1366x768           2.50
# 1284            Intel            Intel         1920x1080           2.50
# 1285            Intel            Intel         3200x1800           2.50
# 1286            Intel            Intel          1366x768           1.60
# 1287              AMD            Intel          1366x768           2.50
# 1288            Intel            Intel          1366x768           1.60
# 1289            Intel            Intel         1920x1080           0.90
# 1290            Intel            Intel          1366x768           2.40
# 1291            Intel            Intel          1366x768           1.60
# 1292            Intel            Intel          1366x768           1.60
# 1293           Nvidia            Intel         1920x1080           2.60
# 1294              AMD              AMD         1920x1080           2.90
# 1295              AMD            Intel          1366x768           2.70
# 1296            Intel            Intel          1366x768           1.60
# 1297           Nvidia            Intel          1366x768           2.50
# 1298            Intel            Intel         1920x1080           2.50
# 1299            Intel            Intel         3200x1800           2.50
# 1300            Intel            Intel          1366x768           1.60
# 1301              AMD            Intel          1366x768           2.50
# 1302            Intel            Intel          1366x768           1.60
#
# [1303 rows x 16 columns]

# %% [markdown]
# ## Filling Missing Values

# %%
laptops['os_version'].value_counts(dropna=False)
# Out:
# 10      1072
# NaN      170
# 7         45
# 10 S       8
# X          8
# Name: os_version, dtype: int64

# %%
os_will_null_v = laptops.loc[laptops['os_version'].isnull(), 'os']
os_will_null_v.value_counts()
# Out:
# No OS        66
# Linux        62
# Chrome OS    27
# macOS        13
# Android       2
# Name: os, dtype: int64

# %%
mac_os_versions = laptops.loc[laptops['os'] == 'macOS', 'os_version']

mac_os_versions.value_counts(dropna=False)
# Out:
# NaN    13
# X       8
# Name: os_version, dtype: int64

# %% [markdown]
# Full name of macOS used to be Mac OS X and so we might need to fill these values to be more consistent.

# %%
value_counts_before = laptops.loc[laptops["os_version"].isnull(), "os"].value_counts()
laptops.loc[laptops["os"] == "macOS", "os_version"] = "X"

value_counts_before
# Out:
# No OS        66
# Linux        62
# Chrome OS    27
# macOS        13
# Android       2
# Name: os, dtype: int64

# %%
# use a boolean array to identify rows that have the value No OS for the os column
# then use assignment to assign the value Version UNknown to the os_version column for those rows
laptops.loc[laptops['os'] == 'No OS', 'os_version'] = 'Version Unknown'

value_counts_after = laptops.loc[laptops['os_version'].isnull(), 'os'].value_counts()

value_counts_after
# Out:
# Linux        62
# Chrome OS    27
# Android       2
# Name: os, dtype: int64

# %% [markdown]
# ## Challenge: Extracting Storage Information

# %%
laptops.loc[76:81, "storage"]
# Out:
# 76                 2TB HDD
# 77    128GB SSD +  1TB HDD
# 78                 1TB HDD
# 79    128GB SSD +  1TB HDD
# 80               256GB SSD
# 81               512GB SSD
# Name: storage, dtype: object

# %% [markdown]
# - some laptops have two disks and some have just one
# - each disk has a capacity (eg 128GB) and a type (eg SSD)
# - capacities are expressed in either gigabytes (GB) or terabytes (TB)

# %%
storage_split = laptops['storage'].str.rsplit(n=4, expand=True)

storage_split.columns = ['storage_1_capacity_gb', 'storage_1_type',
                         '3', 'storage_2_capacity_gb', 'storage_2_type']

storage_split[76:81]
# Out:
#    storage_1_capacity_gb storage_1_type     3 storage_2_capacity_gb  \
# 76                   2TB            HDD  None                  None
# 77                 128GB            SSD     +                   1TB
# 78                   1TB            HDD  None                  None
# 79                 128GB            SSD     +                   1TB
# 80                 256GB            SSD  None                  None
#
#    storage_2_type
# 76           None
# 77            HDD
# 78           None
# 79            HDD
# 80           None

# %%
storage_split['storage_1_capacity_gb'].value_counts(dropna=False)
# Out:
# 256GB         508
# 1TB           250
# 128GB         177
# 512GB         140
# 500GB         132
# 32GB           45
# 2TB            16
# 64GB           16
# 16GB           10
# 1GB             5
# 240GB           1
# 8GB             1
# 508GB           1
# 64GB Flash      1
# Name: storage_1_capacity_gb, dtype: int64

# %%
storage_split['storage_1_type'].value_counts(dropna=False)
# Out:
# SSD        843
# HDD        375
# Flash       74
# Hybrid      10
# Storage      1
# Name: storage_1_type, dtype: int64

# %%
storage_split['storage_2_capacity_gb'].value_counts(dropna=False)
# Out:
# NaN      1095
# 1TB       187
# 2TB        15
# 256GB       3
# 500GB       2
# 512GB       1
# Name: storage_2_capacity_gb, dtype: int64

# %%
storage_split['storage_2_type'].value_counts(dropna=False)
# Out:
# NaN       1095
# HDD        202
# SSD          4
# Hybrid       2
# Name: storage_2_type, dtype: int64

# %%
storage_split['storage_1_capacity_gb'] = (storage_split['storage_1_capacity_gb'].str.strip()
                                          .str.replace('TB','000')
                                          .str.replace('GB','')
                                          .str.replace(' Flash', '')
                                          .astype(float)
                                         )
storage_split['storage_1_capacity_gb'].value_counts(dropna=False)
# Out:
# 256.0     508
# 1000.0    250
# 128.0     177
# 512.0     140
# 500.0     132
# 32.0       45
# 64.0       17
# 2000.0     16
# 16.0       10
# 1.0         5
# 508.0       1
# 8.0         1
# 240.0       1
# Name: storage_1_capacity_gb, dtype: int64

# %%
storage_split['storage_1_type'] = (storage_split['storage_1_type'].str.strip())

storage_split['storage_1_type'].value_counts(dropna=False)
# Out:
# SSD        843
# HDD        375
# Flash       74
# Hybrid      10
# Storage      1
# Name: storage_1_type, dtype: int64

# %%
storage_split['storage_1_type'].describe()
# Out:
# count     1303
# unique       5
# top        SSD
# freq       843
# Name: storage_1_type, dtype: object
